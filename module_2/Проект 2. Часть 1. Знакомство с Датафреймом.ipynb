# %% [markdown]
# Описание датасета
# Посмотрим на переменные, которые содержит датасет:
#
# 1 school — аббревиатура школы, в которой учится ученик
# 2 sex — пол ученика ('F' - женский, 'M' - мужской)
# 3 age — возраст ученика (от 15 до 22)
# 4 address — тип адреса ученика ('U' - городской, 'R' - за городом)
# 5 famsize — размер семьи('LE3' <= 3, 'GT3' >3)
# 6 Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
# 7 Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 8 Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 9 Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# 10 Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# 11 reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
# 12 guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
# 13 traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
# 14 studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
# 15 failures — количество внеучебных неудач (n, если 1<=n<=3, иначе 0)
# 16 schoolsup — дополнительная образовательная поддержка (yes или no)
# 17 famsup — семейная образовательная поддержка (yes или no)
# 18 paid — дополнительные платные занятия по математике (yes или no)
# 19 activities — дополнительные внеучебные занятия (yes или no)
# 20 nursery — посещал детский сад (yes или no)
# 21 higher — хочет получить высшее образование (yes или no)
# 22 internet — наличие интернета дома (yes или no)
# 23 romantic — в романтических отношениях (yes или no)
# 24 famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
# 25 freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)
# 26 goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
# 27 health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
# 28 absences — количество пропущенных занятий
# 29 score — баллы по госэкзамену по математике

# %% [markdown]
# Рекомендации по выполнению проекта
#
# 1 Проведите первичную обработку данных. Так как данных много, стоит написать функции, которые можно применять к столбцам определённого типа.
# 2 Посмотрите на распределение признака для числовых переменных, устраните выбросы.
# 3 Оцените количество уникальных значений для номинативных переменных.
# 4 По необходимости преобразуйте данные
# 5 Проведите корреляционный анализ количественных переменных
# 6 Отберите не коррелирующие переменные.
# 7 Проанализируйте номинативные переменные и устраните те, которые не влияют на предсказываемую величину (в нашем случае — на переменную score).
# 8 Не забудьте сформулировать выводы относительно качества данных и тех переменных, которые вы будете использовать в дальнейшем построении модели.

# %% [markdown]
# Максимальный балл за проект: 20
#
# Проходной балл: 14

# %%
# pip install autopep8

# %%
# conda install -c conda-forge jupyter_contrib_nbextensions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

import numpy as np
import matplotlib as mpl
import warnings

pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колонок
warnings.filterwarnings('ignore') # отплючим лишние предупреждения

stud_math = pd.read_csv('stud_math.csv')

# %% [markdown]
# # Анализ данных

# %%
# Общие функции

# %%
# Посмотрим на наш датасет и колонки его составляющие
display(stud_math.head(5))
stud_math.info()

# %% [markdown]
# можно видеть значительное количество пропусков в данных. (без пропусков как выяснится далее всего 95 строк)

# %%
# узнаем размеры датасета 
print('Датафрейм состоит из:\nСтрок: {}\nСтобцов: {}'.format(stud_math.shape[0], stud_math.shape[1]))
# Out:
# Датафрейм состоит из:
# Строк: 395
# Стобцов: 30

# %%
# посмотрим на пропуски по столбцам
stud_math.isnull().sum().sort_values(ascending=False)
# Out:
# Pstatus               45
# paid                  40
# famsup                39
# Fjob                  36
# internet              34
# romantic              31
# guardian              31
# traveltime            28
# famsize               27
# famrel                27
# Fedu                  24
# failures              22
# higher                20
# Mjob                  19
# reason                17
# address               17
# nursery               16
# health                15
# activities            14
# absences              12
# freetime              11
# schoolsup              9
# goout                  8
# studytime              7
# studytime_granular     7
# score                  6
# Medu                   3
# age                    0
# sex                    0
# school                 0
# dtype: int64

# %% [markdown]
# Судя по распределению пустых значений, абсолютная тайна (если взять гипотезу, что пропуски обозначают отсутствие желания афишировать сферы жизни) это внутрисемейная жизнь.

# %%
# Взглянем на статистику датафрейма включая все столбцы
stud_math.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     378     368     350  392.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     295     261     314         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.750000
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.098127
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  reason guardian  traveltime   studytime  \
# count   371.000000    376    359     378      364  367.000000  388.000000
# ...

# %%
# статистика по числовым данным
stud_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  392.000000  371.000000  367.000000  388.000000  373.000000
# mean    16.696203    2.750000    2.614555    1.438692    2.038660    0.337802
# std      1.276043    1.098127    2.228732    0.694181    0.842078    0.743135
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000   40.000000    4.000000    4.000000    3.000000
#
#        studytime_granular      famrel    freetime       goout      health  \
# count          388.000000  368.000000  384.000000  387.000000  380.000000
# mean            -6.115979    3.937500    3.231771    3.105943    3.531579
# ...

# %% [markdown]
# Названия столбцов удовлетворяют использованию в pandas. Кроме 20  "studytime, granular" - его переименуем в "studytime_granular"

# %%
# Переименуем столбец "studytime, granular"
stud_math.rename(columns={'studytime, granular': 'studytime_granular'}, inplace=True)

# %% [markdown]
# Рассмотрим все столбцы по отдельности: ищем возможности для создания функций по обработке

# %%
for col in stud_math.columns:
    print('Обзор столбца {}'.format(col))
    display(pd.DataFrame(stud_math[col].value_counts()))
    pd.DataFrame(stud_math[col]).info()
    print('\n')
# Out:
# Обзор столбца school
#     school
# GP     349
# MS      46
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   school  395 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
#
#
# Обзор столбца sex
#    sex
# F  208
# M  187
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     395 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
#
#
# Обзор столбца age
#     age
# 16  104
# 17   98
# 18   82
# 15   82
# 19   24
# 20    3
# 22    1
# 21    1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     395 non-null    int64
# dtypes: int64(1)
# ...

# %%
# Проведем первичный визуальный анализ числовых признаков, включим в PairGrid по диагонали гистограмму распределения признака
g = sns.PairGrid(stud_math)
g.map_diag(plt.hist) # гистограмма разпределения признака
g.map_upper(sns.regplot)
g.map_lower(sns.kdeplot)

# %%
sns.catplot(data=stud_math, orient="h", kind="box").set(xscale="log")

# %%
# Проведем первичны визуальный анализ номинативных признаков
for name in stud_math.columns:
    s = ''
    s += name
    if (type(stud_math[name][0]) == str):
        s += ' строка,'
    if (stud_math[name].nunique() <= 3):
        s += ' мало уникальных'
    if (s!=name):
        print (s)
# Out:
# school строка, мало уникальных
# sex строка, мало уникальных
# address строка, мало уникальных
# famsize строка, мало уникальных
# Pstatus строка, мало уникальных
# Mjob строка,
# Fjob строка,
# reason строка,
# guardian строка,
# schoolsup строка, мало уникальных
# famsup строка, мало уникальных
# paid строка, мало уникальных
# activities строка, мало уникальных
# nursery строка, мало уникальных
# higher строка, мало уникальных
# internet строка, мало уникальных
# romantic строка, мало уникальных
# Priznak мало уникальных

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(x=column, y='rating', 
                data=cacao.loc[cacao.loc[:, column].isin(cacao.loc[:, column].value_counts().index[:10])],
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
for col in ['company', 'specific_origin', 'company_location', 'bean_type', 'broad_origin']:
    get_boxplot(col)

# %% [markdown]
# # school — аббревиатура школы, в которой учится ученик

# %% [markdown]
# school содержит два значения: GP (349 раз) и MS (46 раз)
# Данные предоставлены без отклонений и без пропусков.
#
# Гипотеза:
# GP - старшеклассники в общеобразовательнай школе - т.е. кто остался доучиваться в школе
# MS - ВУЗ, те кто не пошел в 10 класс и выбрал обучение рукоделия.
#
# Рассмотрим разделение признака.
# Выбросы в GP вероятно попадают студенты пединститута проходящие в этой школе практику.... (интервьюеры)
# MS - пусть будет просто ВУЗ
#
# GP это более вероятно училище, как раз после 9 класса ушли
# т.е. это судьба учиников некой общеобразовательной школы (моя фантазия - заказ директора школы)
# училище - это ушедшие после не полной средней школы
# ВУЗ - это имеющие полное среднее образование

# %%
# рассмотрим распределение возрастов учеников по признакам
def get_boxplot_x(column, column_y='score'):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(x=column, y=column_y, 
                data=stud_math.loc[stud_math.loc[:, column].isin(stud_math.loc[:, column].value_counts().index[:10])],
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('{}: Boxplot for: {}'.format(column_y, column))
    plt.show()
    
for col in ['age']:
    get_boxplot_x(col, 'school')

# %%
# Посмотрим на влияние причины выбора учебного заведения на общие итоги
ct = pd.crosstab([stud_math.school, stud_math.reason], stud_math['score'])
ct.plot(kind='bar')

ct = pd.crosstab([stud_math.school, stud_math.traveltime], stud_math['score'])
ct.plot(kind='bar')

# %% [markdown]
# # sex — пол ученика ('F' - женский, 'M' - мужской)

# %% [markdown]
# sex содержит два значения: F (208 раз) и M (187 раз)
# Данные предоставлены без отклонений и без пропусков.

# %% [markdown]
# # age — возраст ученика (от 15 до 22)

# %% [markdown]
# Данные предоставлены без пропусков.

# %%
# взглянем на предположительные выбросы.
stud_math[stud_math.age > 19]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T   3.0   1.0  services  services
# 306     GP   M   20       U     GT3       A   3.0   2.0  services     other
# 376     MS   F   20     NaN     GT3       T   4.0   2.0    health     other
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 247   other   mother         1.0        1.0       3.0        no     no   no
# 306  course    other         1.0        1.0       0.0        no     no   no
# 376  course      NaN         2.0        3.0       2.0        no    yes  yes
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
# 392  course      NaN         1.0        1.0       3.0       NaN     no   no
#
# ...

# %% [markdown]
# # address — тип адреса ученика ('U' - городской, 'R' - за городом)

# %% [markdown]
# в выборке видно преобладание городских учеников 295 против загородных 83

# %% [markdown]
# посмотрим на пропуски:

# %%
valid = ['U', 'R']
stud_math[~stud_math.address.isin(valid)].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 6      GP   M   16     NaN     LE3       T   2.0   2.0     other  other
# 52     GP   M   15     NaN     LE3       A   4.0   2.0    health    NaN
# 75     GP   M   15     NaN     GT3       T   4.0   3.0   teacher  other
# 92     GP   F   16     NaN     LE3       T   NaN   1.0     other  other
# 96     GP   M   16     NaN     GT3     NaN   4.0   3.0  services  other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 6         home   mother         1.0        2.0       0.0        no     no
# 52       other   father         2.0        1.0       1.0        no    NaN
# 75        home   mother         1.0        2.0       0.0        no    yes
# 92        home   father         1.0        2.0       0.0       yes    yes
# 96  reputation   mother         2.0        1.0       0.0       yes    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# # famsize — размер семьи('LE3' <= 3, 'GT3' >3)

# %% [markdown]
# в выбрке преобладают ученики из семей размером более 3 человек, их 261, и только 107 из семей размером 3 и менее человек

# %%
# посмотрим на пропуски:
valid = ['LE3', 'GT3']
stud_math[~stud_math.famsize.isin(valid)].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0  at_home   teacher
# 9      GP   M   15       U     NaN     NaN   3.0   4.0    other     other
# 32     GP   M   15       R     NaN       T   4.0   3.0  teacher   at_home
# 36     GP   M   15       U     NaN       T   4.0   3.0  teacher  services
# 76     GP   M   15       U     NaN       T   4.0   0.0  teacher     other
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0   course   mother         2.0        2.0       0.0       yes     no   no
# 9     home   mother         1.0        2.0       0.0        no    yes  yes
# 32  course   mother         1.0        2.0       0.0        no    yes   no
# 36    home   mother         1.0        3.0       0.0        no    yes   no
# 76  course   mother         2.0        4.0       0.0        no     no   no
#
# ...

# %% [markdown]
# # Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)

# %% [markdown]
# Опять же львиная часть (314) родителей учеников живут совместно, против 36 живущих раздельно

# %%
# посмотрим на пропуски:
valid = ['T', 'A']
stud_math[~stud_math.Pstatus.isin(valid)].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1      GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 9      GP   M   15       U     NaN     NaN   3.0   4.0     other     other
# 11     GP   F   15       U     GT3     NaN   2.0  40.0  services     other
# 15     GP   F   16       U     GT3     NaN   4.0   4.0    health     other
# 25     GP   F   16       U     GT3     NaN   2.0   2.0  services  services
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 1       course   father         1.0        2.0       0.0        no    yes
# 9         home   mother         1.0        2.0       0.0        no    yes
# 11  reputation   father         3.0        3.0       0.0        no    yes
# 15        home   mother         1.0        1.0       0.0        no    yes
# 25        home   mother         1.0        1.0       2.0        no    yes
#
# ...

# %% [markdown]
# # Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)

# %% [markdown]
# большинство матерей имеют высшее образование (131), далее по убыванию среднее специальное или 11 классов (102), 5-9 классов (97), 59 матерей имеют образование 4 класса и 3 не имеют образования вообще - сироты?.

# %%
# посмотрим на пропуски:
stud_math[pd.isnull(stud_math.Medu)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 92      GP   F   16     NaN     LE3       T   NaN   1.0     other     other
# 193     GP   M   16       R     GT3     NaN   NaN   3.0  services  services
# 239     GP   M   18       U     GT3     NaN   NaN   2.0     other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 92         home   father         1.0        2.0       0.0       yes    yes
# 193  reputation   mother         1.0        1.0       0.0        no    yes
# 239  reputation   father         1.0        2.0       1.0        no     no
#
#     paid activities nursery  studytime, granular higher internet romantic  \
# 92    no         no     yes                 -6.0    yes       no       no
# 193   no        yes     yes                 -3.0    yes      yes       no
# 239   no         no     yes                 -6.0     no      NaN      NaN
#
#      famrel  freetime  goout  health  absences  score
# ...

# %% [markdown]
# # Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее

# %% [markdown]
# видим выброс равный 40 - возможно опечатка и имеется в виду 4.0 - придеться исправить

# %%
stud_math[stud_math.Fedu == 40]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 11     GP   F   15       U     GT3     NaN   2.0  40.0  services  other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 11  reputation   father         3.0        3.0       0.0        no    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# 11   no        yes     yes                 -9.0    yes      yes       no
#
#     famrel  freetime  goout  health  absences  score
# 11     5.0       2.0    2.0     4.0       4.0   60.0

# %%
# Рассмотрим пропуски
stud_math[stud_math.Fedu.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 21     GP   M   15       U     GT3       T   4.0   NaN    health    health
# 42     GP   M   15       U     GT3       T   4.0   NaN  services   teacher
# 46     GP   F   16       U     LE3       A   3.0   NaN     other  services
# 57     GP   M   15       U     GT3       T   4.0   NaN   teacher    health
# 58     GP   M   15       U     LE3       T   1.0   NaN     other   at_home
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 21       other   father         1.0        1.0       NaN        no    yes
# 42      course   father         1.0        2.0       0.0        no    yes
# 46        home   mother         1.0        2.0       0.0        no    yes
# 57  reputation   mother         1.0        2.0       0.0        no    yes
# 58        home   father         1.0        2.0       0.0       yes    yes
#
# ...

# %% [markdown]
# # Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)

# %% [markdown]
# 376 из 395 записей заполнено. в заполненных данных противоречей не видно.

# %%
# Посмотрим на пропуски
stud_math[stud_math.Mjob.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu Mjob     Fjob  \
# 29      GP   M   16       U     GT3       T   4.0   4.0  NaN  teacher
# 54      GP   F   15       U     LE3     NaN   3.0   3.0  NaN    other
# 59      GP   F   16       U     GT3       T   4.0   2.0  NaN      NaN
# 88      GP   M   16       U     GT3       T   2.0   2.0  NaN    other
# 104     GP   M   15       U     GT3       A   3.0   4.0  NaN    other
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 29         home   mother         1.0        2.0       0.0        no    yes
# 54        other   mother         1.0        1.0       NaN        no     no
# 59       course   mother         NaN        2.0       0.0        no    NaN
# 88   reputation   father         2.0        2.0       1.0        no     no
# 104      course   mother         NaN        2.0       0.0        no    yes
#
#     paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# # Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)

# %% [markdown]
# 359 из 395 записей заполнено. в заполненных данных противоречей не видно.

# %%
# Посмотрим на пропуски
stud_math[stud_math.Fjob.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob Fjob  \
# 3      GP   F   15       U     GT3       T   4.0   2.0    health  NaN
# 17     GP   F   16       U     GT3       T   3.0   3.0     other  NaN
# 22     GP   M   16       U     LE3       T   4.0   2.0   teacher  NaN
# 26     GP   M   15       U     GT3       T   2.0   2.0     other  NaN
# 31     GP   M   15       U     GT3       T   4.0   4.0  services  NaN
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 3         home   mother         1.0        3.0       0.0        no    yes
# 17  reputation   mother         3.0        NaN       0.0       yes    NaN
# 22      course   mother         1.0        2.0       0.0        no    NaN
# 26        home   mother         NaN        1.0       0.0        no    yes
# 31  reputation   mother         2.0        2.0       0.0        no    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# # reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)

# %% [markdown]
# 378 из 395 записей заполнено. в заполненных данных противоречей не видно. Основные причины выбора школы - наличие образовательной программы, близость к дому и наличие положительной репутации

# %%
# Посмотрим на пропуски
stud_math[stud_math.reason.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob    Fjob  \
# 33      GP   M   15       U     LE3       T   3.0   3.0    other   other
# 63      GP   F   16       U     GT3     NaN   4.0   3.0  teacher  health
# 73      GP   M   16       U     GT3       T   3.0   1.0    other   other
# 77      GP   F   16       U     GT3       T   2.0   2.0    other   other
# 112     GP   F   16       U     GT3     NaN   2.0   2.0  at_home   other
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 33     NaN   mother         1.0        2.0       0.0        no    NaN   no
# 63     NaN   mother         1.0        3.0       0.0       yes    yes  yes
# 73     NaN   mother         1.0        1.0       0.0        no     no   no
# 77     NaN   mother         1.0        4.0       0.0        no     no  yes
# 112    NaN   mother         NaN        NaN       1.0       yes     no   no
#
# ...

# %% [markdown]
# # guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
# 11  guardian             364 non-null    object

# %% [markdown]
# 364 из 395 записей заполнено. в заполненных данных противоречей не видно. Как обычно в современном обществе главенствующая роль в опекунстве лежит на матерях.

# %%
# Посмотрим на пропуски
stud_math[stud_math.guardian.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 38     GP   F   15       R     GT3       T   3.0   4.0  services    health
# 41     GP   M   15       U     LE3       T   4.0   4.0   teacher     other
# 49     GP   F   15       U     GT3       T   4.0   4.0  services   teacher
# 53     GP   F   15       U     GT3       T   4.0   4.0  services  services
# 60     GP   F   16       R     GT3       T   4.0   4.0    health   teacher
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 38  course      NaN         1.0        3.0       0.0       yes    NaN  yes
# 41    home      NaN         1.0        1.0       0.0        no    yes   no
# 49   other      NaN         1.0        2.0       1.0       yes    yes   no
# 53  course      NaN         1.0        1.0       0.0       yes    yes  yes
# 60   other      NaN         1.0        2.0       0.0        no    yes   no
#
# ...

# %% [markdown]
# # traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)

# %% [markdown]
# 367 из 395 записей заполнено. в заполненных данных противоречей не видно. Абсолютное большенство живет в шаговой доступности.

# %%
# Посмотрим на пропуски
stud_math[stud_math.traveltime.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu    Mjob      Fjob  \
# 26     GP   M   15       U     GT3       T   2.0   2.0   other       NaN
# 30     GP   M   15       U     GT3       T   4.0   4.0  health  services
# 35     GP   F   15       U     GT3       T   2.0   3.0   other     other
# 37     GP   M   16       R     GT3       A   4.0   4.0   other   teacher
# 59     GP   F   16       U     GT3       T   4.0   2.0     NaN       NaN
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 26        home   mother         NaN        1.0       0.0        no    yes
# 30        home   mother         NaN        2.0       0.0        no    yes
# 35       other   father         NaN        1.0       0.0       NaN    yes
# 37  reputation   mother         NaN        3.0       0.0        no    yes
# 59      course   mother         NaN        2.0       0.0        no    NaN
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# # studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)

# %%
Большинство учеников уделяют внеклассной работе от 2 до 5 часов в неделю (194 человека)

# %%
# Посмотрим на пропуски
stud_math[stud_math.studytime.isna()]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 17      GP   F   16       U     GT3       T   3.0   3.0     other       NaN
# 91      GP   F   15       U     GT3       T   4.0   3.0  services     other
# 112     GP   F   16       U     GT3     NaN   2.0   2.0   at_home     other
# 129     GP   M   16       R     NaN       T   4.0   4.0   teacher   teacher
# 227     GP   M   17       U     LE3     NaN   2.0   3.0  services  services
# 266     GP   M   17       U     GT3     NaN   3.0   1.0  services       NaN
# 314     GP   F   19       U     GT3       T   1.0   1.0   at_home    health
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 17   reputation   mother         3.0        NaN       0.0       yes    NaN
# 91   reputation   mother         1.0        NaN       NaN        no     no
# 112         NaN   mother         NaN        NaN       1.0       yes     no
# ...

# %% [markdown]
# # failures — количество внеучебных неудач (n, если 1<=n<=3, иначе 0)

# %%
имеем 373 показателя, которые явно обозначают отсутствие внеучебных неудач (293)

# %%
# Посмотрим на пропуски
stud_math[stud_math.failures.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob    Fjob  \
# 21     GP   M   15       U     GT3       T   4.0   NaN    health  health
# 48     GP   M   15       U     GT3       T   4.0   2.0   teacher   other
# 54     GP   F   15       U     LE3     NaN   3.0   3.0       NaN   other
# 68     GP   F   15       R     LE3       T   2.0   2.0    health     NaN
# 91     GP   F   15       U     GT3       T   4.0   3.0  services   other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 21       other   father         1.0        1.0       NaN        no    yes
# 48        home   mother         1.0        2.0       NaN        no    yes
# 54       other   mother         1.0        1.0       NaN        no     no
# 68  reputation   mother         NaN        2.0       NaN       yes    yes
# 91  reputation   mother         1.0        NaN       NaN        no     no
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# # schoolsup — дополнительная образовательная поддержка (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.schoolsup.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 27      GP   M   15       U     GT3       T   4.0   2.0    health  services
# 35      GP   F   15       U     GT3       T   2.0   3.0     other     other
# 79      GP   F   16       U     NaN       T   3.0   4.0   at_home     other
# 151     GP   M   16       U     LE3       T   2.0   1.0   at_home       NaN
# 211     GP   M   17       U     LE3       T   4.0   4.0  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 27    other   mother         1.0        1.0       0.0       NaN     no  yes
# 35    other   father         NaN        1.0       0.0       NaN    yes   no
# 79   course   mother         1.0        2.0       0.0       NaN    yes   no
# 151  course   mother         1.0        1.0       1.0       NaN     no   no
# 211    home   mother         1.0        2.0       0.0       NaN    yes  yes
#
# ...

# %% [markdown]
# Алсолютное большинство не имеет дополнительной образовательной поддержки (335)

# %% [markdown]
# # famsup — семейная образовательная поддержка (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.famsup.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob    Fjob  \
# 17     GP   F   16       U     GT3       T   3.0   3.0     other     NaN
# 22     GP   M   16       U     LE3       T   4.0   2.0   teacher     NaN
# 28     GP   M   16       U     LE3     NaN   3.0   4.0  services   other
# 33     GP   M   15       U     LE3       T   3.0   3.0     other   other
# 38     GP   F   15       R     GT3       T   3.0   4.0  services  health
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 17  reputation   mother         3.0        NaN       0.0       yes    NaN
# 22      course   mother         1.0        2.0       0.0        no    NaN
# 28        home   mother         1.0        2.0       0.0       yes    NaN
# 33         NaN   mother         1.0        2.0       0.0        no    NaN
# 38      course      NaN         1.0        3.0       0.0       yes    NaN
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# Большинство учеников имеют семейную образовательную поддержку (219)

# %% [markdown]
# # paid — дополнительные платные занятия по математике (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.paid.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 18     GP   M   17       U     GT3       T   3.0   2.0  services  services
# 19     GP   M   16       U     LE3       T   4.0   3.0    health     other
# 21     GP   M   15       U     GT3       T   4.0   NaN    health    health
# 26     GP   M   15       U     GT3       T   2.0   2.0     other       NaN
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 2    other   mother         1.0        2.0       3.0       yes     no  NaN
# 18  course   mother         1.0        1.0       3.0        no    yes  NaN
# 19    home   father         1.0        1.0       0.0        no     no  NaN
# 21   other   father         1.0        1.0       NaN        no    yes  NaN
# 26    home   mother         NaN        1.0       0.0        no    yes  NaN
#
# ...

# %% [markdown]
# С деньгами рады расстаться всего 155 семей.

# %% [markdown]
# # activities — дополнительные внеучебные занятия (yes или no)

# %%
display(pd.DataFrame(stud_math.activities.value_counts()))
stud_math.activities.hist()
# Out:
#      activities
# yes         195
# no          186

# %%
# Посмотрим на пропуски
stud_math[stud_math.activities.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 43     GP   M   15       U     GT3       T   2.0   2.0  services  services
# 44     GP   F   16       U     LE3       T   2.0   2.0     other       NaN
# 54     GP   F   15       U     LE3     NaN   3.0   3.0       NaN     other
# 81     GP   M   15       U     GT3     NaN   2.0   3.0     other     other
# 99     GP   F   16       U     GT3       T   4.0   3.0     other   at_home
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 43  course   father         1.0        1.0       0.0       yes    yes   no
# 44  course   father         2.0        2.0       1.0       yes     no   no
# 54   other   mother         1.0        1.0       NaN        no     no  yes
# 81    home      NaN         1.0        3.0       0.0       yes     no  NaN
# 99  course   mother         1.0        3.0       0.0       yes    yes  yes
#
# ...

# %% [markdown]
# Посещают дополнительные внеучебные занятия 195 учеников

# %% [markdown]
# # nursery — посещал детский сад (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.nursery.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 22      GP   M   16       U     LE3       T   4.0   2.0   teacher       NaN
# 32      GP   M   15       R     NaN       T   4.0   3.0   teacher   at_home
# 85      GP   F   15       U     GT3       T   4.0   4.0  services  services
# 88      GP   M   16       U     GT3       T   2.0   2.0       NaN     other
# 152     GP   F   15       R     GT3       T   3.0   3.0  services       NaN
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 22       course   mother         1.0        2.0       0.0        no    NaN
# 32       course   mother         1.0        2.0       0.0        no    yes
# 85   reputation   father         2.0        2.0       2.0        no     no
# 88   reputation   father         2.0        2.0       1.0        no     no
# 152  reputation    other         2.0        3.0       2.0        no    yes
#
# ...

# %% [markdown]
# 300 учеников посещали дошкольные заведения

# %% [markdown]
# # higher — хочет получить высшее образование (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.higher.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 34     GP   M   16       U     GT3       T   3.0   2.0     other  other
# 48     GP   M   15       U     GT3       T   4.0   2.0   teacher  other
# 76     GP   M   15       U     NaN       T   4.0   0.0   teacher  other
# 84     GP   F   15       U     GT3       T   1.0   1.0     other  other
# 96     GP   M   16     NaN     GT3     NaN   4.0   3.0  services  other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 34        home   mother         1.0        1.0       0.0        no    yes
# 48        home   mother         1.0        2.0       NaN        no    yes
# 76      course   mother         2.0        4.0       0.0        no     no
# 84        home   father         1.0        2.0       0.0        no    yes
# 96  reputation   mother         2.0        1.0       0.0       yes    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# ...

# %% [markdown]
# 356 учеников мечтают о высшем образовании

# %% [markdown]
# # internet — наличие интернета дома (yes или no)

# %%
display(pd.DataFrame(stud_math.internet.value_counts()))
stud_math.internet.hist()
# Out:
#      internet
# yes       305
# no         56

# %%
# Посмотрим на пропуски
stud_math[stud_math.internet.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0  at_home   teacher
# 12     GP   M   15       U     LE3       T   4.0   4.0   health  services
# 52     GP   M   15     NaN     LE3       A   4.0   2.0   health       NaN
# 65     GP   F   16       U     LE3       T   4.0   3.0  teacher  services
# 80     GP   M   15       U     GT3       T   2.0   3.0    other  services
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0   course   mother         2.0        2.0       0.0       yes     no   no
# 12  course   father         1.0        1.0       0.0        no    yes  yes
# 52   other   father         2.0        1.0       1.0        no    NaN   no
# 65  course   mother         3.0        2.0       0.0        no    yes   no
# 80  course   father         1.0        1.0       0.0       yes    yes  yes
#
# ...

# %% [markdown]
# странно для 21 века но 56 учеников не имеют доступа к интернету ( 14.18 %)

# %%
stud_math.internet.value_counts()[1] / stud_math.shape[0] * 100
# Out:
# 14.177215189873419

# %% [markdown]
# # romantic — в романтических отношениях (yes или no)

# %%
# Посмотрим на пропуски
stud_math[stud_math.romantic.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 2      GP   F   15       U     LE3       T   1.0   1.0  at_home     other
# 13     GP   M   15       U     GT3       T   4.0   3.0  teacher     other
# 26     GP   M   15       U     GT3       T   2.0   2.0    other       NaN
# 27     GP   M   15       U     GT3       T   4.0   2.0   health  services
# 41     GP   M   15       U     LE3       T   4.0   4.0  teacher     other
#
#     reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 2    other   mother         1.0        2.0       3.0       yes     no  NaN
# 13  course   mother         2.0        2.0       0.0        no    yes  yes
# 26    home   mother         NaN        1.0       0.0        no    yes  NaN
# 27   other   mother         1.0        1.0       0.0       NaN     no  yes
# 41    home      NaN         1.0        1.0       0.0        no    yes   no
#
# ...

# %% [markdown]
# большей части учеников романтика еще не познана (240)

# %% [markdown]
# # famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)

# %% [markdown]
# видим выброс: -1, либо очень плохо в семье (ежедневное битье), либо опечатка 1 - возможно придется заменить на 1

# %%
# рассмотри потенциальный выброс
stud_math[stud_math.famrel == -1]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 25     GP   F   16       U     GT3     NaN   2.0   2.0  services  services
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 25   home   mother         1.0        1.0       2.0        no    yes  yes
#
#    activities nursery  studytime, granular higher internet romantic  famrel  \
# 25         no      no                 -3.0    yes      yes       no    -1.0
#
#     freetime  goout  health  absences  score
# 25       2.0    2.0     5.0      14.0   40.0

# %%
# Посмотрим на пропуски
stud_math[stud_math.famrel.isna()].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 12     GP   M   15       U     LE3       T   4.0   4.0    health  services
# 20     GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 43     GP   M   15       U     GT3       T   2.0   2.0  services  services
# 72     GP   F   15       R     GT3       T   1.0   1.0     other     other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 8         home   mother         1.0        2.0       0.0        no    yes
# 12      course   father         1.0        1.0       0.0        no    yes
# 20  reputation   mother         1.0        2.0       0.0        no     no
# 43      course   father         1.0        1.0       0.0       yes    yes
# 72  reputation   mother         1.0        2.0       2.0       yes    yes
#
# ...

# %% [markdown]
# # freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)

# %%
# Посмотрим на пропуски
stud_math[stud_math.freetime.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 32      GP   M   15       R     NaN       T   4.0   3.0   teacher   at_home
# 74      GP   F   16       U     GT3       T   3.0   3.0     other  services
# 131     GP   F   15       U     GT3     NaN   1.0   1.0   at_home     other
# 201     GP   F   16       U     GT3       T   2.0   3.0     other     other
# 280     GP   M   17       U     NaN       A   4.0   NaN  services     other
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 32       course   mother         1.0        2.0       0.0        no    yes
# 74         home   mother         1.0        2.0       0.0       yes    yes
# 131      course   mother         3.0        1.0       0.0        no    yes
# 201  reputation   mother         1.0        2.0       0.0       yes    yes
# 280        home   mother         2.0        1.0       NaN        no     no
#
# ...

# %% [markdown]
# # goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)

# %%
# Посмотрим на пропуски
stud_math[stud_math.goout.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob    Fjob  \
# 89      GP   M   16       U     LE3       A   4.0   4.0  teacher  health
# 92      GP   F   16     NaN     LE3       T   NaN   1.0    other   other
# 200     GP   F   16       U     GT3       T   4.0   3.0   health   other
# 202     GP   F   17       U     NaN       T   1.0   1.0    other   other
# 221     GP   F   17       U     NaN       T   1.0   1.0  at_home   other
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 89   reputation   mother         1.0        2.0       0.0        no    yes
# 92         home   father         1.0        2.0       0.0       yes    yes
# 200        home   mother         1.0        2.0       0.0        no    yes
# 202      course   mother         1.0        2.0       0.0        no    yes
# 221  reputation   mother         1.0        3.0       1.0        no    yes
#
# ...

# %% [markdown]
# # health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)

# %%
# Посмотрим на пропуски
stud_math[stud_math.health.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 30      GP   M   15       U     GT3       T   4.0   4.0    health  services
# 55      GP   F   16       U     GT3       A   2.0   1.0     other     other
# 88      GP   M   16       U     GT3       T   2.0   2.0       NaN     other
# 145     GP   F   15       U     GT3       T   1.0   1.0       NaN  services
# 153     GP   M   19       U     GT3     NaN   3.0   2.0  services   at_home
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 30         home   mother         NaN        2.0       0.0        no    yes
# 55        other   mother         1.0        2.0       0.0        no     no
# 88   reputation   father         2.0        2.0       1.0        no     no
# 145      course   father         1.0        2.0       0.0        no    yes
# 153        home   mother         1.0        1.0       NaN        no    yes
#
# ...

# %% [markdown]
# большинство относят себя к зодорой части населения

# %% [markdown]
# # absences — количество пропущенных занятий

# %%
# Произведем отсев выбросов (дни пропуска больше 60, таких в датасете оказалось 3 шт.)
stud_math[stud_math.absences>=60.0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 222     GP   F   16       U     GT3       T   2.0   3.0  services   teacher
# 276     GP   F   18       R     GT3       A   3.0   2.0     other  services
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 222   other   mother         1.0        2.0       0.0       yes    NaN   no
# 276    home   mother         2.0        2.0       0.0        no    NaN   no
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 222         no     yes                 -6.0    yes      yes       no     2.0
# 276         no      no                 -6.0     no      yes      yes     NaN
# 390         no     yes                 -6.0    yes       no       no     5.0
#
# ...

# %%
# Посмотрим на пропуски
stud_math[stud_math.absences.isna()].head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 24      GP   F   15       R     GT3       T   2.0   4.0  services   health
# 101     GP   M   16       U     GT3       T   4.0   4.0  services  teacher
# 120     GP   F   15       U     GT3       T   1.0   2.0   at_home      NaN
# 129     GP   M   16       R     NaN       T   4.0   4.0   teacher  teacher
# 150     GP   M   18       U     LE3       T   1.0   1.0     other    other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 24   course   mother         1.0        3.0       0.0       yes    yes  yes
# 101   other   father         1.0        3.0       0.0        no    yes   no
# 120  course   mother         1.0        2.0       0.0        no     no   no
# 129  course   mother         1.0        NaN       0.0        no     no  yes
# 150  course   mother         1.0        1.0       3.0        no     no   no
#
# ...

# %% [markdown]
# # score — баллы по госэкзамену по математике

# %%
display(pd.DataFrame(stud_math.score.value_counts()))
stud_math.score.hist()
# Out:
#        score
# 50.0      54
# 55.0      46
# 0.0       37
# 75.0      33
# 65.0      31
# 40.0      31
# 60.0      31
# 70.0      27
# 45.0      27
# 80.0      16
# 30.0      15
# 90.0      12
# 35.0       9
# 25.0       7
# 85.0       6
# 95.0       5
# 100.0      1
# 20.0       1

# %%
# взглянем на лидиров броунеровского дважиения - получивших 0 баловв по экзамену. варианты - не участвовали
stud_math[stud_math.score == 0]
# оснвная часть из школы GP
# интересно, что абсолютное большинство из них не получают дополнительной образовательной поддержки (schoolsup)
# но и странно, у них практически нет пропусков занятий (absences)
# Out:
#     school sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob  \
# 128     GP   M   18        R  No data        T   2.0   2.0   No data
# 130     GP   F   15        R      GT3        T   3.0   4.0  services
# 131     GP   F   15        U      GT3  No data   1.0   1.0   at_home
# 134     GP   M   15        R      GT3        T   3.0   4.0   at_home
# 135     GP   F   15        U      GT3        T   4.0   4.0  services
# 136     GP   M   17        R      GT3        T   3.0   4.0   at_home
# 137     GP   F   16        U      GT3        A   3.0   2.0     other
# 140     GP   M   15        U      GT3        T   4.0   3.0   teacher
# 144     GP   M   17        U      GT3        T   2.0   1.0     other
# 146     GP   F   15        U      GT3        T   3.0   2.0    health
# 148     GP   M   16        U      GT3        T   4.0   4.0   teacher
# 150     GP   M   18        U      LE3        T   1.0   1.0     other
# 153     GP   M   19        U      GT3  No data   3.0   2.0  services
# ...

# %% [markdown]
# Основной объект исследования.

# %%
# Посмотрим на пропуски
stud_math[stud_math.score.isna()]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  \
# 201     GP   F   16       U     GT3       T   2.0   3.0  other     other
# 244     GP   F   18       U     GT3       T   2.0   1.0  other     other
# 270     GP   F   19     NaN     GT3       T   3.0   3.0  other  services
# 283     GP   F   18       U     GT3       T   1.0   1.0  other     other
# 312     GP   M   19       U     GT3       T   1.0   2.0  other  services
# 350     MS   M   19     NaN     GT3       T   1.0   1.0  other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 201  reputation   mother         1.0        2.0       0.0       yes    yes
# 244      course    other         2.0        3.0       0.0        no    yes
# 270        home    other         1.0        2.0       2.0        no    yes
# 283        home   mother         2.0        2.0       0.0       yes    NaN
# 312      course    other         1.0        2.0       1.0        no     no
# ...

# %% [markdown]
# # Первичная обработка данных.

# %%
stud_math = pd.read_csv('stud_math.csv')

# создание столбца признака и заполнение его данными о пропусках Priznak
# 0 - данные - по умолчанию
# 1 - пропуски
# 2 - выбросы
stud_math['Priznak'] = 0

# Заполним пропуски стандартными значениями: медиана и фраза нет данных
for col in list(stud_math):
    # заполним 'Priznak' = 1 в строках содержащих пропуски
    stud_math.loc[stud_math[col].isna(), 'Priznak'] = 1
    if stud_math[col].dtypes == 'object':
        stud_math.loc[stud_math[col].isna(), [col]] = 'No data'
    if stud_math[col].dtypes == 'float64':
        stud_math.loc[stud_math[col].isna(), [col]] = stud_math[col].median()

# сильная коррекция
# display(stud_math[(stud_math.Priznak == 1)][['studytime', 'studytime, granular']])
# 'studytime, granular' можно удалять: *= -3 
del stud_math['studytime, granular']

# отмечаем выбросы

# stud_math['age'] Метим вылетами возраст 22, 21 - нужно изучать школьный возраст в стране исходнике
stud_math.loc[stud_math.age >19, 'Priznak'] = 2
# stud_math['Fedu'] видим выброс равный 40 - возможно опечатка и имеется в виду 4.0 - исправиm
stud_math.loc[stud_math.Fedu == 40, 'Priznak'] = 2
stud_math.loc[stud_math.Fedu == 40, 'Fedu'] = 4
# stud_math['absences'] выбросим злостный прогульщиков (пропуски больше 60 занятий - таких три ученика)
stud_math.loc[stud_math.absences>=60.0, 'Priznak'] = 2
# stud_math['famrel'] выбросим несчастного постоянно избитого ученика
stud_math.loc[stud_math.famrel == -1, 'Priznak'] = 2



print('Выведем очищенные данные:')
print('Признак выброс (2)')
display(stud_math[(stud_math.Priznak == 2)])
print('Свод по данным без выбросов - наш исходник для дальнейшей работы (не равно 2)')
stud_math[(stud_math.Priznak != 2)].info()

# Сохраним данные Датафрейма для дальнейшей работы
stud_math[(stud_math.Priznak != 2)].to_csv('stud_math_och.csv', index=False)
# Out:
# Выведем очищенные данные:
# Признак выброс (2)
#     school sex  age  address famsize  Pstatus  Medu  Fedu      Mjob      Fjob  \
# 11      GP   F   15        U     GT3  No data   2.0   4.0  services     other
# 25      GP   F   16        U     GT3  No data   2.0   2.0  services  services
# 222     GP   F   16        U     GT3        T   2.0   3.0  services   teacher
# 247     GP   M   22        U     GT3        T   3.0   1.0  services  services
# 276     GP   F   18        R     GT3        A   3.0   2.0     other  services
# 306     GP   M   20        U     GT3        A   3.0   2.0  services     other
# 376     MS   F   20  No data     GT3        T   4.0   2.0    health     other
# 390     MS   M   20        U     LE3        A   2.0   2.0  services  services
# 392     MS   M   21        R     GT3        T   1.0   1.0     other     other
#
#          reason guardian  traveltime  studytime  failures schoolsup   famsup  \
# ...

# %%
stud_math[stud_math.absences>=60.0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 222     GP   F   16       U     GT3       T   2.0   3.0  services   teacher
# 276     GP   F   18       R     GT3       A   3.0   2.0     other  services
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
#
#      reason guardian  traveltime  studytime  failures schoolsup   famsup paid  \
# 222   other   mother         1.0        2.0       0.0       yes  No data   no
# 276    home   mother         2.0        2.0       0.0        no  No data   no
# 390  course  No data         1.0        2.0       2.0        no      yes  yes
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 222         no     yes    yes      yes       no     2.0       3.0    1.0
# 276         no      no     no      yes      yes     4.0       1.0    1.0
# 390         no     yes    yes       no       no     5.0       5.0    4.0
#
#      health  absences  score  Priznak
# ...

# %% [markdown]
# Принимаем волевое решение: т.к. в рекомендациях нет указания по заполнению пропусков - оставляем датафрейм как есть, но держим в уме, что он слишком дырявый.
#
# Переходим к части 2 данной работы.
